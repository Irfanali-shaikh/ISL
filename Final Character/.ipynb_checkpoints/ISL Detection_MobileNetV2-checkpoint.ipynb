# %% [markdown]
# ## ISL Using (MobileNetV2)

# %%
import tensorflow as tf
import pandas as pd 
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Activation, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img, array_to_img, img_to_array
from tensorflow.keras.models import Sequential
from glob import glob

# %%
# Define Constants by re-sizing all the images
IMAGE_SIZE = [224, 224]

train_path = "C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\"

# %%
# Import the InceptionV3 model and here we will be using imagenet weights

mobilenet = MobileNetV2(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# We don't need to train existing weights
for layer in mobilenet.layers:
    layer.trainable = False

# %%
# Folders in the Training Set
folders = glob('C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\*')
folders
# Out:
# ['C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\A',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\B',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\C',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\D',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\E',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\F',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\G',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\H',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\I',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\J',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\K',
#  'C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\L',
# ...

# %%
# Model layers -> can add more if required
x = Flatten()(mobilenet.output)
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# Create a model object
model = Model(inputs=mobilenet.input, outputs=prediction)

# View the structure of the model
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_3[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
# Defining the cost and model optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# Using the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Training Generator
training_set = train_datagen.flow_from_directory('C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 32400 images belonging to 27 classes.

# %%
# Testing Generator
test_set = test_datagen.flow_from_directory('C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 3193 images belonging to 27 classes.

# %%
# fit the model, it will take some time to execute
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=10,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# C:\Users\rashm\AppData\Local\Temp/ipykernel_11568/1141776482.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   r = model.fit_generator(
# Epoch 1/10
# 1013/1013 [==============================] - 281s 275ms/step - loss: 0.0730 - accuracy: 0.9950 - val_loss: 0.0013 - val_accuracy: 0.9997
# Epoch 2/10
# 1013/1013 [==============================] - 282s 279ms/step - loss: 0.0902 - accuracy: 0.9971 - val_loss: 0.3024 - val_accuracy: 0.9915
# Epoch 3/10
# 1013/1013 [==============================] - 275s 271ms/step - loss: 0.0068 - accuracy: 0.9997 - val_loss: 0.1488 - val_accuracy: 0.9966
# Epoch 4/10
# 1013/1013 [==============================] - 271s 268ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/10
# ...

# %%
# Plot the Loss and Accuracy
# Loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# Accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
from tensorflow.keras.models import load_model
model.save('C:\\Users\\rashm\\Downloads\\ISL_character\\Untitled Folder\\Indian\\ISL_mobileNET.h5')
